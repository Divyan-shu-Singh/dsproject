# %%
from box import ConfigBox

example_config = ConfigBox({
    "app_name": "My Application",
    "version": "1.0.0",
})

# %%
example_config["app_name"]
# Out:
# 'My Application'

# %%
example_config.app_name
# Out:
# 'My Application'
